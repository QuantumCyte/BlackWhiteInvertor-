# %%
import cv2
import numpy as np
import os

# %%
for file in os.listdir('originalPrintfiles'):
    print(file)
    file_path = os.path.join('originalPrintfiles', file)
    img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

    _, thresh = cv2.threshold(img, 50, 255, cv2.THRESH_BINARY_INV)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    biggest_contour = max(contours, key=cv2.contourArea)

    mask = np.zeros_like(img)

    cv2.drawContours(mask, [biggest_contour], -1, 255, thickness=-1)

    inverted = cv2.bitwise_not(img)

    result = np.where(mask == 255, inverted, img)

    finalResultFile = os.path.join('invertedPrintfiles', f'inverted_{file}')

    cv2.imwrite(finalResultFile, result)

    print(f'Processed and saved: {finalResultFile}')
# Out:
# 100622B-2PRINTFILE.png
# Processed and saved: invertedPrintfiles\inverted_100622B-2PRINTFILE.png
